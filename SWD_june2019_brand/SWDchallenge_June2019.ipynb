# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('SWDchallenge_june2019.csv')

# %%
''.join([df.year[0], df.month[0]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-312ef0c0bb40> in <module>
# ----> 1 ''.join([df.year[0], df.month[0]])
#
# TypeError: sequence item 0: expected str instance, numpy.int64 found

# %%
df
# Out:
#       status  year      month  sales
# 0     ACTUAL  2018    January   1.61
# 1     ACTUAL  2018   February   1.63
# 2     ACTUAL  2018      March   1.74
# 3     ACTUAL  2018      April   1.69
# 4     ACTUAL  2018        May   1.80
# 5     ACTUAL  2018       June   1.87
# 6     ACTUAL  2018       July   1.54
# 7     ACTUAL  2018     August   1.56
# 8     ACTUAL  2018  September   1.61
# 9     ACTUAL  2018    October   1.57
# 10    ACTUAL  2018   November   1.59
# 11    ACTUAL  2018   December   1.61
# 12    ACTUAL  2019    January   1.58
# 13    ACTUAL  2019   February   1.80
# 14    ACTUAL  2019      March   1.89
# 15    ACTUAL  2019      April   1.91
# 16    ACTUAL  2019        May   1.97
# 17  FORECAST  2019       June   2.01
# 18  FORECAST  2019       July   2.07
# 19  FORECAST  2019     August   2.11
# 20  FORECAST  2019  September   2.17
# 21  FORECAST  2019    October   2.24
# 22  FORECAST  2019   November   2.31
# 23  FORECAST  2019   December   2.37

# %%
df.apply(lambda r: r[])
